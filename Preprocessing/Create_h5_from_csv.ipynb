# %%
import chess
import h5py
import numpy as np
import pandas as pd

# Define the board positions mapping
board_positions = {
    'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4, 'f': 5, 'g': 6, 'h': 7
}

# Function to convert chess square to board index
def square_to_index(square):
    letter = chess.square_name(square)
    row = 8 - int(letter[1])
    column = board_positions[letter[0]]
    return row, column

# Function to convert board to matrix
def board_to_matrix(board):
    board_3d = np.zeros((14, 8, 8), dtype=np.int8)

    for piece in chess.PIECE_TYPES:
        for square in board.pieces(piece, chess.WHITE):
            index = np.unravel_index(square, (8, 8))
            board_3d[piece - 1][7 - index[0]][index[1]] = 1

        for square in board.pieces(piece, chess.BLACK):
            index = np.unravel_index(square, (8, 8))
            board_3d[piece + 5][7 - index[0]][index[1]] = 1

    aux = board.turn
    board.turn = chess.WHITE
    for move in board.legal_moves:
        i, j = square_to_index(move.to_square)
        board_3d[12][i][j] = 1

    board.turn = chess.BLACK
    for move in board.legal_moves:
        i, j = square_to_index(move.to_square)
        board_3d[13][i][j] = 1

    board.turn = aux

    return board_3d

# Function to pad lists to ensure they have five elements
def pad_list(lst, length=5, pad_value=None):
    return lst + [pad_value] * (length - len(lst))

# Function to process and save boards
def process_and_save_boards(csv_file, output_file, batch_size=1000):
    df = pd.read_csv(csv_file)
    total_boards = len(df)
    
    with h5py.File(output_file, "w") as hf_out:
        hf_out.create_dataset("board_matrix", (total_boards, 14, 8, 8), dtype=np.int8)
        hf_out.create_dataset("GameID", (total_boards,), dtype=np.int32)
        hf_out.create_dataset("MoveID", (total_boards,), dtype=np.int32)
        hf_out.create_dataset("PlayerMove", (total_boards,), dtype=h5py.string_dtype(encoding='utf-8'))
        hf_out.create_dataset("TopMoves", (total_boards, 5), dtype=h5py.string_dtype(encoding='utf-8'))
        hf_out.create_dataset("BestMove", (total_boards,), dtype=h5py.string_dtype(encoding='utf-8'))
        hf_out.create_dataset("Centipawns", (total_boards, 5),  dtype=np.int32)
        hf_out.create_dataset("Mates", (total_boards, 5),  dtype=np.int32)
        hf_out.create_dataset("MoveSequence", (total_boards, 5), dtype=h5py.string_dtype(encoding='utf-8'))
        hf_out.create_dataset("Player", (total_boards,), dtype=h5py.string_dtype(encoding='utf-8'))

        count = 0

        while count < total_boards:
            batch = df[count:count+batch_size]
            for idx, row in batch.iterrows():
                fen = row["FEN"]
                board = chess.Board(fen)
                board_matrix = board_to_matrix(board)
                
                hf_out["board_matrix"][idx] = board_matrix
                hf_out["GameID"][idx] = row["GameID"]
                hf_out["MoveID"][idx] = row["MoveID"]
                hf_out["PlayerMove"][idx] = row["Move"]
                hf_out["TopMoves"][idx] = pad_list(row["TopMoves"].strip('[]').replace("'", "").split(", "), 5, "")
                hf_out["BestMove"][idx] = row["BestMove"]
                
                # Convert Centipawns and Mates from string to list of integers, pad if necessary
                hf_out["Centipawns"][idx] = pad_list([int(x) if x != 'None' else 0 for x in row["Centipawns"].strip('[]').split(', ')], 5, 0)
                hf_out["Mates"][idx] = pad_list([int(x) if x != 'None' else 0 for x in row["Mates"].strip('[]').split(', ')], 5, 0)
                
                hf_out["MoveSequence"][idx] = pad_list(row["MoveSequence"].strip('[]').replace("'", "").split(", "), 5, "")
                hf_out["Player"][idx] = row["Player"]
            count += batch_size
            print(f"Processed {min(count, total_boards)} / {total_boards} boards.")

        print("Processing complete.")

if __name__ == "__main__":
    csv_file = "./enhanced_magnus_moves_dataset_v3.csv"  # replace with your CSV file path
    output_file = "magnus_datasetv3.h5"  # replace with your desired output file path
    process_and_save_boards(csv_file, output_file)
# Out:
# Processed 1000 / 223622 boards.
# Processed 2000 / 223622 boards.
# Processed 3000 / 223622 boards.
# Processed 4000 / 223622 boards.
# Processed 5000 / 223622 boards.
# Processed 6000 / 223622 boards.
# Processed 7000 / 223622 boards.
# Processed 8000 / 223622 boards.
# Processed 9000 / 223622 boards.
# Processed 10000 / 223622 boards.
# Processed 11000 / 223622 boards.
# Processed 12000 / 223622 boards.
# Processed 13000 / 223622 boards.
# Processed 14000 / 223622 boards.
# Processed 15000 / 223622 boards.
# Processed 16000 / 223622 boards.
# Processed 17000 / 223622 boards.
# Processed 18000 / 223622 boards.
# Processed 19000 / 223622 boards.
# Processed 20000 / 223622 boards.
# Processed 21000 / 223622 boards.
# Processed 22000 / 223622 boards.
# Processed 23000 / 223622 boards.
# Processed 24000 / 223622 boards.
# Processed 25000 / 223622 boards.
# Processed 26000 / 223622 boards.
# Processed 27000 / 223622 boards.
# Processed 28000 / 223622 boards.
# Processed 29000 / 223622 boards.
# Processed 30000 / 223622 boards.
# Processed 31000 / 223622 boards.
# Processed 32000 / 223622 boards.
# Processed 33000 / 223622 boards.
# Processed 34000 / 223622 boards.
# Processed 35000 / 223622 boards.
# Processed 36000 / 223622 boards.
# Processed 37000 / 223622 boards.
# Processed 38000 / 223622 boards.
# Processed 39000 / 223622 boards.
# Processed 40000 / 223622 boards.
# Processed 41000 / 223622 boards.
# Processed 42000 / 223622 boards.
# Processed 43000 / 223622 boards.
# Processed 44000 / 223622 boards.
# Processed 45000 / 223622 boards.
# Processed 46000 / 223622 boards.
# Processed 47000 / 223622 boards.
# Processed 48000 / 223622 boards.
# Processed 49000 / 223622 boards.
# Processed 50000 / 223622 boards.
# Processed 51000 / 223622 boards.
# Processed 52000 / 223622 boards.
# Processed 53000 / 223622 boards.
# Processed 54000 / 223622 boards.
# Processed 55000 / 223622 boards.
# Processed 56000 / 223622 boards.
# Processed 57000 / 223622 boards.
# Processed 58000 / 223622 boards.
# Processed 59000 / 223622 boards.
# Processed 60000 / 223622 boards.
# Processed 61000 / 223622 boards.
# Processed 62000 / 223622 boards.
# Processed 63000 / 223622 boards.
# Processed 64000 / 223622 boards.
# Processed 65000 / 223622 boards.
# Processed 66000 / 223622 boards.
# Processed 67000 / 223622 boards.
# Processed 68000 / 223622 boards.
# Processed 69000 / 223622 boards.
# Processed 70000 / 223622 boards.
# Processed 71000 / 223622 boards.
# Processed 72000 / 223622 boards.
# Processed 73000 / 223622 boards.
# Processed 74000 / 223622 boards.
# Processed 75000 / 223622 boards.
# Processed 76000 / 223622 boards.
# Processed 77000 / 223622 boards.
# Processed 78000 / 223622 boards.
# Processed 79000 / 223622 boards.
# Processed 80000 / 223622 boards.
# Processed 81000 / 223622 boards.
# Processed 82000 / 223622 boards.
# Processed 83000 / 223622 boards.
# Processed 84000 / 223622 boards.
# Processed 85000 / 223622 boards.
# Processed 86000 / 223622 boards.
# Processed 87000 / 223622 boards.
# Processed 88000 / 223622 boards.
# Processed 89000 / 223622 boards.
# Processed 90000 / 223622 boards.
# Processed 91000 / 223622 boards.
# Processed 92000 / 223622 boards.
# Processed 93000 / 223622 boards.
# Processed 94000 / 223622 boards.
# Processed 95000 / 223622 boards.
# Processed 96000 / 223622 boards.
# Processed 97000 / 223622 boards.
# Processed 98000 / 223622 boards.
# Processed 99000 / 223622 boards.
# Processed 100000 / 223622 boards.
# Processed 101000 / 223622 boards.
# Processed 102000 / 223622 boards.
# Processed 103000 / 223622 boards.
# Processed 104000 / 223622 boards.
# Processed 105000 / 223622 boards.
# Processed 106000 / 223622 boards.
# Processed 107000 / 223622 boards.
# Processed 108000 / 223622 boards.
# Processed 109000 / 223622 boards.
# Processed 110000 / 223622 boards.
# Processed 111000 / 223622 boards.
# Processed 112000 / 223622 boards.
# Processed 113000 / 223622 boards.
# Processed 114000 / 223622 boards.
# Processed 115000 / 223622 boards.
# Processed 116000 / 223622 boards.
# Processed 117000 / 223622 boards.
# Processed 118000 / 223622 boards.
# Processed 119000 / 223622 boards.
# Processed 120000 / 223622 boards.
# Processed 121000 / 223622 boards.
# Processed 122000 / 223622 boards.
# Processed 123000 / 223622 boards.
# Processed 124000 / 223622 boards.
# Processed 125000 / 223622 boards.
# Processed 126000 / 223622 boards.
# Processed 127000 / 223622 boards.
# Processed 128000 / 223622 boards.
# Processed 129000 / 223622 boards.
# Processed 130000 / 223622 boards.
# Processed 131000 / 223622 boards.
# Processed 132000 / 223622 boards.
# Processed 133000 / 223622 boards.
# Processed 134000 / 223622 boards.
# Processed 135000 / 223622 boards.
# Processed 136000 / 223622 boards.
# Processed 137000 / 223622 boards.
# Processed 138000 / 223622 boards.
# Processed 139000 / 223622 boards.
# Processed 140000 / 223622 boards.
# Processed 141000 / 223622 boards.
# Processed 142000 / 223622 boards.
# Processed 143000 / 223622 boards.
# Processed 144000 / 223622 boards.
# Processed 145000 / 223622 boards.
# Processed 146000 / 223622 boards.
# Processed 147000 / 223622 boards.
# Processed 148000 / 223622 boards.
# Processed 149000 / 223622 boards.
# Processed 150000 / 223622 boards.
# Processed 151000 / 223622 boards.
# Processed 152000 / 223622 boards.
# Processed 153000 / 223622 boards.
# Processed 154000 / 223622 boards.
# Processed 155000 / 223622 boards.
# Processed 156000 / 223622 boards.
# Processed 157000 / 223622 boards.
# Processed 158000 / 223622 boards.
# Processed 159000 / 223622 boards.
# Processed 160000 / 223622 boards.
# Processed 161000 / 223622 boards.
# Processed 162000 / 223622 boards.
# Processed 163000 / 223622 boards.
# Processed 164000 / 223622 boards.
# Processed 165000 / 223622 boards.
# Processed 166000 / 223622 boards.
# Processed 167000 / 223622 boards.
# Processed 168000 / 223622 boards.
# Processed 169000 / 223622 boards.
# Processed 170000 / 223622 boards.
# Processed 171000 / 223622 boards.
# Processed 172000 / 223622 boards.
# Processed 173000 / 223622 boards.
# Processed 174000 / 223622 boards.
# Processed 175000 / 223622 boards.
# Processed 176000 / 223622 boards.
# Processed 177000 / 223622 boards.
# Processed 178000 / 223622 boards.
# Processed 179000 / 223622 boards.
# Processed 180000 / 223622 boards.
# Processed 181000 / 223622 boards.
# Processed 182000 / 223622 boards.
# Processed 183000 / 223622 boards.
# Processed 184000 / 223622 boards.
# Processed 185000 / 223622 boards.
# Processed 186000 / 223622 boards.
# Processed 187000 / 223622 boards.
# Processed 188000 / 223622 boards.
# Processed 189000 / 223622 boards.
# Processed 190000 / 223622 boards.
# Processed 191000 / 223622 boards.
# Processed 192000 / 223622 boards.
# Processed 193000 / 223622 boards.
# Processed 194000 / 223622 boards.
# Processed 195000 / 223622 boards.
# Processed 196000 / 223622 boards.
# Processed 197000 / 223622 boards.
# Processed 198000 / 223622 boards.
# Processed 199000 / 223622 boards.
# Processed 200000 / 223622 boards.
# Processed 201000 / 223622 boards.
# Processed 202000 / 223622 boards.
# Processed 203000 / 223622 boards.
# Processed 204000 / 223622 boards.
# Processed 205000 / 223622 boards.
# Processed 206000 / 223622 boards.
# Processed 207000 / 223622 boards.
# Processed 208000 / 223622 boards.
# Processed 209000 / 223622 boards.
# Processed 210000 / 223622 boards.
# Processed 211000 / 223622 boards.
# Processed 212000 / 223622 boards.
# Processed 213000 / 223622 boards.
# Processed 214000 / 223622 boards.
# Processed 215000 / 223622 boards.
# Processed 216000 / 223622 boards.
# Processed 217000 / 223622 boards.
# Processed 218000 / 223622 boards.
# Processed 219000 / 223622 boards.
# Processed 220000 / 223622 boards.
# Processed 221000 / 223622 boards.
# Processed 222000 / 223622 boards.
# Processed 223000 / 223622 boards.
# Processed 223622 / 223622 boards.
# Processing complete.
